# %%
# Import modules
import dill                     # pip install dill
import matplotlib.pyplot as plt # pip install matplotlib

# %%
dill.load_session("model.db")

# %%
epochs = range(n_epochs+1)
print(error_history)
print(epochs)
# Out:
# [2.3142866950613374, 0.2158195500764289, 0.1483558269166987, 0.11175580066138488, 0.08824457015232857, 0.07294588601493639, 0.06230777433167946, 0.05432548970333759, 0.04823275573280712, 0.043177141667009374, 0.03940393409873572, 0.03444812188379264, 0.030912217110797592, 0.028284203686540995, 0.02488177865763659, 0.022128201655865355, 0.01908600201451603, 0.01685147467564, 0.015237164833454725, 0.013615408501711512, 0.012568671729898867]
# range(0, 21)

# %%
plt.plot(epochs, error_history)
plt.xlabel('epochs')
plt.ylabel('loss_val')
plt.show()
